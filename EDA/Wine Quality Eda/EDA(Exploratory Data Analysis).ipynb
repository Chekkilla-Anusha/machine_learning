# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\anush\OneDrive\Desktop\WineQT.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.nunique()
# Out:
# fixed acidity             91
# volatile acidity         135
# citric acid               77
# residual sugar            80
# chlorides                131
# free sulfur dioxide       53
# total sulfur dioxide     138
# density                  388
# pH                        87
# sulphates                 89
# alcohol                   61
# quality                    6
# Id                      1143
# dtype: int64

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
(df.isnull().sum()/(len(df)))*100
# Out:
# fixed acidity           0.0
# volatile acidity        0.0
# citric acid             0.0
# residual sugar          0.0
# chlorides               0.0
# free sulfur dioxide     0.0
# total sulfur dioxide    0.0
# density                 0.0
# pH                      0.0
# sulphates               0.0
# alcohol                 0.0
# quality                 0.0
# Id                      0.0
# dtype: float64

# %%
if 'S.No.' in df.columns:
    df = df.drop(['S.No.'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
print(df.columns)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
df['sugar_level'] = pd.cut(df['residual sugar'], bins=[0, 2, 5, 10, 100], labels=['Low', 'Medium', 'High', 'Very High'])
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id sugar_level
# 0      9.4        5   0         Low
# ...

# %%
df['acidity_level'] = pd.cut(df['pH'], bins=[0, 3, 3.5, 4, 14], labels=['High', 'Medium', 'Low', 'Very Low'])
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id sugar_level acidity_level
# ...

# %%
df['alcohol_strength'] = pd.cut(df['alcohol'], bins=[0, 10, 12, 14, 20], 
                                labels=['Low', 'Medium', 'High', 'Very High'])
df['sugar_level'] = pd.cut(df['residual sugar'], bins=[0, 2, 5, 10, 100], 
                           labels=['Low', 'Medium', 'High', 'Very High'])
df[['quality', 'acidity_level', 'sugar_level', 'alcohol_strength']].head()
# Out:
#    quality acidity_level sugar_level alcohol_strength
# 0        5           Low         Low              Low
# 1        5        Medium      Medium              Low
# 2        5        Medium      Medium              Low
# 3        6        Medium         Low              Low
# 4        5           Low         Low              Low

# %%
# Check unique categories
print("Acidity levels:", df['acidity_level'].unique())
print("Number of acidity levels:", df['acidity_level'].nunique())

print("Sugar levels:", df['sugar_level'].unique())
print("Number of sugar levels:", df['sugar_level'].nunique())

print("Alcohol strength levels:", df['alcohol_strength'].unique())
print("Number of alcohol strength levels:", df['alcohol_strength'].nunique())
# Out:
# Acidity levels: ['Low', 'Medium', 'High', 'Very Low']
# Categories (4, object): ['High' < 'Medium' < 'Low' < 'Very Low']
# Number of acidity levels: 4
# Sugar levels: ['Low', 'Medium', 'High', 'Very High']
# Categories (4, object): ['Low' < 'Medium' < 'High' < 'Very High']
# Number of sugar levels: 4
# Alcohol strength levels: ['Low', 'Medium', 'High', 'Very High']
# Categories (4, object): ['Low' < 'Medium' < 'High' < 'Very High']
# Number of alcohol strength levels: 4

# %%
searchfor_acidity = ['High', 'Medium'] 
searchfor_sugar = ['High']               
filtered_df = df[
    df['acidity_level'].isin(searchfor_acidity) &
    df['sugar_level'].isin(searchfor_sugar)
]


filtered_df.head(5)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 25             7.8             0.645         0.00             5.5      0.086
# 28             7.3             0.450         0.36             5.9      0.074
# 106            7.1             0.430         0.42             5.5      0.071
# 107            7.1             0.430         0.42             5.5      0.070
# 108            7.1             0.430         0.42             5.5      0.071
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 25                   5.0                  18.0   0.9986  3.40       0.55
# 28                  12.0                  87.0   0.9978  3.33       0.83
# 106                 28.0                 128.0   0.9973  3.42       0.71
# 107                 29.0                 129.0   0.9973  3.42       0.72
# 108                 28.0                 128.0   0.9973  3.42       0.71
#
# ...

# %%
#to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df["acidity_level"].replace({ "Very Low": "Low", "Medium": "Med"}, inplace=True)
df["sugar_level"].replace({"Very High": "High","Medium": "Med"}, inplace=True)
print(df["acidity_level"].unique())
print(df["sugar_level"].unique())
# Out:
# ['Low', 'Med', 'High']
# Categories (3, object): ['High' < 'Med' < 'Low']
# ['Low', 'Med', 'High']
# Categories (3, object): ['Low' < 'Med' < 'High']

# %%
 df.duplicated().sum()
# Out:
# np.int64(0)

# %%
 df.duplicated().mean()
# Out:
# np.float64(0.0)

# %%
 df.duplicated().mode()
# Out:
# 0    False
# dtype: bool

# %%
#  Statistics Summary
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.describe().T
# Out:
#                        count        mean         std      min        25%  \
# fixed acidity         1143.0    8.311111    1.747595  4.60000    7.10000
# volatile acidity      1143.0    0.531339    0.179633  0.12000    0.39250
# citric acid           1143.0    0.268364    0.196686  0.00000    0.09000
# residual sugar        1143.0    2.532152    1.355917  0.90000    1.90000
# chlorides             1143.0    0.086933    0.047267  0.01200    0.07000
# free sulfur dioxide   1143.0   15.615486   10.250486  1.00000    7.00000
# total sulfur dioxide  1143.0   45.914698   32.782130  6.00000   21.00000
# density               1143.0    0.996730    0.001925  0.99007    0.99557
# pH                    1143.0    3.311015    0.156664  2.74000    3.20500
# sulphates             1143.0    0.657708    0.170399  0.33000    0.55000
# alcohol               1143.0   10.442111    1.082196  8.40000    9.50000
# quality               1143.0    5.657043    0.805824  3.00000    5.00000
# ...

# %%
df.describe(include='all').T
# Out:
#                        count unique  top freq        mean         std  \
# fixed acidity         1143.0    NaN  NaN  NaN    8.311111    1.747595
# volatile acidity      1143.0    NaN  NaN  NaN    0.531339    0.179633
# citric acid           1143.0    NaN  NaN  NaN    0.268364    0.196686
# residual sugar        1143.0    NaN  NaN  NaN    2.532152    1.355917
# chlorides             1143.0    NaN  NaN  NaN    0.086933    0.047267
# free sulfur dioxide   1143.0    NaN  NaN  NaN   15.615486   10.250486
# total sulfur dioxide  1143.0    NaN  NaN  NaN   45.914698    32.78213
# density               1143.0    NaN  NaN  NaN     0.99673    0.001925
# pH                    1143.0    NaN  NaN  NaN    3.311015    0.156664
# sulphates             1143.0    NaN  NaN  NaN    0.657708    0.170399
# alcohol               1143.0    NaN  NaN  NaN   10.442111    1.082196
# quality               1143.0    NaN  NaN  NaN    5.657043    0.805824
# ...

# %%
plt.figure(figsize=(8,5))
sns.countplot( x='quality',  data=df,  palette='viridis', order=sorted(df['quality'].unique()) )
plt.title('Wine Quality Distribution', fontsize=16)
plt.xlabel('Quality Score', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %%
sns.set_style("darkgrid")
numerical_columns = df.select_dtypes(include=["int64", "float64"]).columns
plt.figure(figsize=(14, len(numerical_columns) * 3))
for idx, feature in enumerate(numerical_columns, 1):
    plt.subplot(len(numerical_columns), 2, idx)
    sns.histplot(df[feature], kde=True)
    plt.title(f"{feature} | Skewness: {round(df[feature].skew(), 2)}")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))

sns.swarmplot(x="quality", y="alcohol", data=df, palette='viridis')

plt.title('Swarm Plot for Quality and Alcohol')
plt.xlabel('Quality')
plt.ylabel('Alcohol')
plt.show()

# %%
# Bivariate Analysis

# %%
sns.set_palette("Pastel1")

plt.figure(figsize=(10, 6))

sns.pairplot(df)

plt.suptitle('Pair Plot for DataFrame')
plt.show()

# %%
df['quality'] = df['quality'].astype(str)  

plt.figure(figsize=(10, 8))

sns.violinplot(x="quality", y="alcohol", data=df, palette={
               '3': 'lightcoral', '4': 'lightblue', '5': 'lightgreen', '6': 'gold', '7': 'lightskyblue', '8': 'lightpink'}, alpha=0.7)

plt.title('Violin Plot for Quality and Alcohol')
plt.xlabel('Quality')
plt.ylabel('Alcohol')
plt.show()

# %%
sns.boxplot(x='quality', y='alcohol', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
numeric_cols = df.select_dtypes(include='number').columns

plt.figure(figsize=(15, 10))
sns.heatmap( df[numeric_cols].corr(),   annot=True, fmt='.2f', cmap='Pastel2', linewidths=2)
plt.title('Correlation Heatmap (Numeric Features Only)', fontsize=16)
plt.show()
